# %% [markdown]
# <a href="https://colab.research.google.com/github/candelapalomeque/NLP/blob/main/Word_Cloud_Candela_Palomeque.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyreadr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Ucrania

# %%
import pyreadr
result = pyreadr.read_r('/content/noticiasUcraniaDF.RDS')

# %%
df = result[None]

# %%
noti = df['Noticia']

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# True

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
import nltk

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
stopwords = set(stopwords.words('spanish')) 
set_names = set(df["Noticia"]) 
list_names = (list(set_names))
for i in list_names:
  print("-------------------------------------------------------------------------------------------------")
  print(i)
  print("-------------------------------------------------------------------------------------------------")
  myval1 = i
  newdf = df.query("Noticia == @myval1")
  for j in newdf.Noticia:
    text = ""
    text = text + " " + j
  shortword = re.compile(r'\W*\b\w{1,3}\b')
  text = shortword.sub('', text)
  wordcloud = WordCloud(stopwords=stopwords).generate(text)
  plt.imshow(wordcloud, interpolation='bilinear')
  plt.axis("off")
  plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# -------------------------------------------------------------------------------------------------
# ...
